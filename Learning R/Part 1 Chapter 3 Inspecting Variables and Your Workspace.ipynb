# %% [markdown]
# # Part 1 Chapter 3 Inspecting Variables and Your Workspace

# %% [markdown]
# ## Classes

# %%
class(c(TRUE, FALSE))
# Out:
# [1] "logical"

# %% [markdown]
# ## Different Types of Numbers

# %%
sqrt(1:10)
# Out:
#  [1] 1.000000 1.414214 1.732051 2.000000 2.236068 2.449490 2.645751 2.828427
#  [9] 3.000000 3.162278

# %%
class(sqrt(1:10))
# Out:
# [1] "numeric"

# %%
class(3+1i)
# Out:
# [1] "complex"

# %%
class(1)
# Out:
# [1] "numeric"

# %%
0.5:4.5
# Out:
# [1] 0.5 1.5 2.5 3.5 4.5

# %%
class(0.5:4.5)
# Out:
# [1] "numeric"

# %%
class(1:5)
# Out:
# [1] "integer"

# %% [markdown]
# ## Other Common Classes

# %%
class(c("she","sells","seashells","on","the","sea","shore"))
# Out:
# [1] "character"

# %%
gender <- factor(c("male","female"，"female","male","female"))
gender
# Out:
# [1] male   female female male   female
# Levels: female male

# %%
levels(gender)
# Out:
# [1] "female" "male"

# %%
nlevels(gender)
# Out:
# [1] 2

# %% [markdown]
# - the factor values are stored as integers rather than characters

# %%
gender
# Out:
# [1] male   female female male   female
# Levels: female male

# %%
as.integer(gender)
# Out:
# [1] 2 1 1 2 1

# %%
gender_char <- sample(c("female","male"), 10000, replace=TRUE)
gender_char
# Out:
#     [1] "male"   "female" "male"   "male"   "male"   "male"   "female" "male"
#     [9] "male"   "male"   "male"   "male"   "male"   "male"   "female" "male"
#    [17] "male"   "female" "female" "female" "male"   "female" "male"   "female"
#    [25] "male"   "male"   "female" "male"   "female" "male"   "female" "female"
#    [33] "male"   "female" "male"   "male"   "male"   "male"   "female" "male"
#    [41] "female" "male"   "female" "male"   "male"   "male"   "male"   "male"
#    [49] "female" "male"   "female" "female" "female" "female" "male"   "female"
#    [57] "male"   "male"   "female" "female" "female" "female" "male"   "male"
#    [65] "male"   "female" "female" "female" "female" "male"   "female" "female"
#    [73] "female" "male"   "male"   "male"   "male"   "male"   "female" "female"
#    [81] "male"   "male"   "male"   "male"   "female" "female" "male"   "female"
#    [89] "male"   "female" "male"   "female" "female" "male"   "male"   "female"
# ...

# %%
gender_fac <- as.factor(gender_char)
gender_fac
# Out:
#     [1] male   female male   male   male   male   female male   male   male
#    [11] male   male   male   male   female male   male   female female female
#    [21] male   female male   female male   male   female male   female male
#    [31] female female male   female male   male   male   male   female male
#    [41] female male   female male   male   male   male   male   female male
#    [51] female female female female male   female male   male   female female
#    [61] female female male   male   male   female female female female male
#    [71] female female female male   male   male   male   male   female female
#    [81] male   male   male   male   female female male   female male   female
#    [91] male   female female male   male   female female male   female female
#   [101] male   female female male   male   female male   male   male   male
#   [111] female female male   female female female female female male   female
# ...

# %%
object.size(gender_char)
# Out:
# 80160 bytes

# %%
object.size(gender_fac)
# Out:
# 40560 bytes

# %% [markdown]
# - a factor containing the values takes up less memory than the character equivalent
# - convert into a factor using as.factor
# - object.size() returns the memory allocation for each object

# %%
gender
# Out:
# [1] male   female female male   female
# Levels: female male

# %%
class(gender)
# Out:
# [1] "factor"

# %%
as.character(gender)
# Out:
# [1] "male"   "female" "female" "male"   "female"

# %% [markdown]
# ### raw 不想看
# - page 51-52

# %% [markdown]
# ## Checking and Changing Classes

# %%
is.character("red lorry, yellow lorry!")
# Out:
# [1] TRUE

# %%
is.logical(FALSE)
# Out:
# [1] TRUE

# %%
is.list(list(a=1, b=2))
# Out:
# [1] TRUE

# %%
# - we can see a complete list of is functions in the base package using:

ls(pattern = "^is", baseenv())
# Out:
#  [1] "is.array"                "is.atomic"
#  [3] "is.call"                 "is.character"
#  [5] "is.complex"              "is.data.frame"
#  [7] "is.double"               "is.element"
#  [9] "is.environment"          "is.expression"
# [11] "is.factor"               "is.finite"
# [13] "is.function"             "is.infinite"
# [15] "is.integer"              "is.language"
# [17] "is.list"                 "is.loaded"
# [19] "is.logical"              "is.matrix"
# [21] "is.na"                   "is.na.data.frame"
# [23] "is.na.numeric_version"   "is.na.POSIXlt"
# [25] "is.na<-"                 "is.na<-.default"
# [27] "is.na<-.factor"          "is.na<-.numeric_version"
# [29] "is.name"                 "is.nan"
# [31] "is.null"                 "is.numeric"
# [33] "is.numeric.Date"         "is.numeric.difftime"
# [35] "is.numeric.POSIXt"       "is.numeric_version"
# [37] "is.object"               "is.ordered"
# [39] "is.package_version"      "is.pairlist"
# ...

# %%
is.numeric(1)
# Out:
# [1] TRUE

# %%
is.numeric(1L)
# Out:
# [1] TRUE

# %%
# note that adding an L suffix makes the number into an integer:

is.integer(1)  # important
# Out:
# [1] FALSE

# %%
# note that adding an L suffix makes the number into an integer:

is.integer(1L)
# Out:
# [1] TRUE

# %%
is.double(1)
# Out:
# [1] TRUE

# %%
is.double(1L)
# Out:
# [1] FALSE

# %%
x<- "123.456"
as.double(x)
# Out:
# [1] 123.456

# %%
as(x, "numeric")
# Out:
# [1] 123.456

# %%
as.numeric(x)
# Out:
# [1] 123.456

# %%
y<- c(2,12,343, 34997)
y
# Out:
# [1]     2    12   343 34997

# %%
as.data.frame(y)
# Out:
#   y
# 1     2
# 2    12
# 3   343
# 4 34997

# %%
x<- "123.456"
class(x)
# Out:
# [1] "character"

# %%
class(x)<- "numeric"
x
# Out:
# [1] 123.456

# %%
is.numeric(x)
# Out:
# [1] TRUE

# %% [markdown]
# ## Examing Variables

# %%
ulams_spiral <- c(1,8,23,46,77)

for (i in ulams_spiral)
    i

i
# Out:
# [1] 77

# %%
for (i in ulams_spiral)
    print(i)
# Out:
# [1] 1
# [1] 8
# [1] 23
# [1] 46
# [1] 77

# %%
num<- runif(30)
num
# Out:
#  [1] 0.91234266 0.22586457 0.18282775 0.83495733 0.83584409 0.54410985
#  [7] 0.23327386 0.81918271 0.36076118 0.88368940 0.66593288 0.81184191
# [13] 0.62705220 0.30191233 0.80539036 0.73961544 0.54582760 0.55483963
# [19] 0.02314638 0.42876826 0.65123676 0.54340384 0.58925396 0.68272072
# [25] 0.26266990 0.69746563 0.73474811 0.91079243 0.10200795 0.48159772

# %%
summary(num)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.02315 0.37776 0.60815 0.56644 0.78895 0.91234

# %%
sample(letters[1:5], 30, replace = TRUE)
# Out:
#  [1] "b" "b" "d" "b" "b" "d" "d" "d" "b" "d" "d" "b" "e" "e" "e" "b" "b" "e" "d"
# [20] "b" "a" "d" "e" "a" "c" "a" "d" "d" "d" "a"

# %%
fac <- factor(sample(letters[1:5], 30, replace = TRUE))

fac
# Out:
#  [1] a c e e a e b a b e c a e b c a e e b b c d e e a e c d b a
# Levels: a b c d e

# %%
summary(fac)
# Out:
#  a  b  c  d  e
#  7  6  5  2 10

# %%
bool <- sample(c(TRUE, FALSE, NA), 30, replace = TRUE)
summary(bool)
# Out:
#    Mode   FALSE    TRUE    NA's
# logical       8      13       9

# %%
print(length(num))
num
# Out:
# [1] 30
#  [1] 0.91234266 0.22586457 0.18282775 0.83495733 0.83584409 0.54410985
#  [7] 0.23327386 0.81918271 0.36076118 0.88368940 0.66593288 0.81184191
# [13] 0.62705220 0.30191233 0.80539036 0.73961544 0.54582760 0.55483963
# [19] 0.02314638 0.42876826 0.65123676 0.54340384 0.58925396 0.68272072
# [25] 0.26266990 0.69746563 0.73474811 0.91079243 0.10200795 0.48159772

# %%
df <- data.frame(num,fac, bool)
df
# Out:
#    num        fac bool
# 1  0.91234266 a   FALSE
# 2  0.22586457 c   FALSE
# 3  0.18282775 e      NA
# 4  0.83495733 e    TRUE
# 5  0.83584409 a    TRUE
# 6  0.54410985 e    TRUE
# 7  0.23327386 b      NA
# 8  0.81918271 a    TRUE
# 9  0.36076118 b      NA
# 10 0.88368940 e    TRUE
# 11 0.66593288 c   FALSE
# 12 0.81184191 a   FALSE
# 13 0.62705220 e   FALSE
# 14 0.30191233 b    TRUE
# 15 0.80539036 c    TRUE
# 16 0.73961544 a   FALSE
# 17 0.54582760 e    TRUE
# 18 0.55483963 e    TRUE
# 19 0.02314638 b      NA
# 20 0.42876826 b      NA
# 21 0.65123676 c      NA
# 22 0.54340384 d   FALSE
# 23 0.58925396 e    TRUE
# 24 0.68272072 e      NA
# 25 0.26266990 a      NA
# 26 0.69746563 e    TRUE
# 27 0.73474811 c    TRUE
# 28 0.91079243 d      NA
# 29 0.10200795 b   FALSE
# 30 0.48159772 a    TRUE

# %%
head(df)
# Out:
#   num       fac bool
# 1 0.9123427 a   FALSE
# 2 0.2258646 c   FALSE
# 3 0.1828278 e      NA
# 4 0.8349573 e    TRUE
# 5 0.8358441 a    TRUE
# 6 0.5441098 e    TRUE

# %%
summary(df)
# Out:
#       num          fac       bool
#  Min.   :0.02315   a: 7   Mode :logical
#  1st Qu.:0.37776   b: 6   FALSE:8
#  Median :0.60815   c: 5   TRUE :13
#  Mean   :0.56644   d: 2   NA's :9
#  3rd Qu.:0.78895   e:10
#  Max.   :0.91234

# %%
str(num)
# Out:
#  num [1:30] 0.912 0.226 0.183 0.835 0.836 ...

# %%
str(df)
# Out:
# 'data.frame':	30 obs. of  3 variables:
#  $ num : num  0.912 0.226 0.183 0.835 0.836 ...
#  $ fac : Factor w/ 5 levels "a","b","c","d",..: 1 3 5 5 1 5 2 1 2 5 ...
#  $ bool: logi  FALSE FALSE NA TRUE TRUE TRUE ...

# %%
print(str(fac))
print(class(fac))
fac
# Out:
#  Factor w/ 5 levels "a","b","c","d",..: 1 3 5 5 1 5 2 1 2 5 ...
# NULL
# [1] "factor"
#  [1] a c e e a e b a b e c a e b c a e e b b c d e e a e c d b a
# Levels: a b c d e

# %%
# unclass()是得到一个整数，而且不是四舍五入之类的取整，而是放大单位
unclass(fac)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
#  [1] 1 3 5 5 1 5 2 1 2 5 3 1 5 2 3 1 5 5 2 2 3 4 5 5 1 5 3 4 2 1
# attr(,"levels")
# [1] "a" "b" "c" "d" "e"

# %%
as.factor(fac)
# Out:
#  [1] a c e e a e b a b e c a e b c a e e b b c d e e a e c d b a
# Levels: a b c d e

# %%
unclass(fac)
# Out:
#  [1] 1 3 5 5 1 5 2 1 2 5 3 1 5 2 3 1 5 5 2 2 3 4 5 5 1 5 3 4 2 1
# attr(,"levels")
# [1] "a" "b" "c" "d" "e"

# %%
# attributes function gives a list of all the attributes belonging to an object 
attributes(fac)
# Out:
# $levels
# [1] "a" "b" "c" "d" "e"
#
# $class
# [1] "factor"

# %%
## The Workspace 
peach<- 1 
plum <- "fruity"
pear <- TRUE
ls()
# Out:
#  [1] "bool"         "df"           "fac"          "gender"       "gender_char"
#  [6] "gender_fac"   "i"            "num"          "peach"        "pear"
# [11] "plum"         "ulams_spiral" "x"            "y"

# %%
browseEnv()
# Out:
# R objects in .GlobalEnv environment is shown in browser

# %%
rm(peach, plum, pear)

# %%
ls()
# Out:
#  [1] "bool"         "df"           "fac"          "gender"       "gender_char"
#  [6] "gender_fac"   "i"            "num"          "ulams_spiral" "x"
# [11] "y"

# %%
rm(list = ls())

# %%
ls()
# Out:
# character(0)
